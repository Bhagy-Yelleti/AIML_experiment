# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhagy-Yelleti/AIML_experiment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic syntax
print("Hello, PyCharm!")  # Output a string

# Data types
x: int = 5
y: float = 3.14
name: str = "Alice"
flag: bool = True

print(x, y, name, flag)
# Out:
# Hello, PyCharm!
# 5 3.14 Alice True

# %%
# If-else
x = 5

if x > 0:
    print("x is positive")
else:
    print("x is zero or negative")


# For loop
for i in range(3):
    print("Loop:", i)


# While loop
count = 0

while count < 3:
    print("Count:", count)
    count += 1
# Out:
# x is positive
# Loop: 0
# Loop: 1
# Loop: 2
# Count: 0
# Count: 1
# Count: 2
